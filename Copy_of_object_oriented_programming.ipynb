# %%
# Class

# %%
#  A class is a blueprint uesd to create objects

# %%
class student:
     pass

# %%
class teachers:
     pass

# %%
class Staff:
      pass

# %%
# Object

# %%
# An instance is an instance of a class

# %%
class studentobject:
    pass

# %%
s1 = studentobject

# %%
class Teachersobject:
      pass

# %%
s1 = Teachersobject

# %%
print(type(s1))
# Out:
# <class '__main__.student'>

# %%
print(type(T1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7173/2847426337.py in <cell line: 0>()
# ----> 1 print(type(T1))
#
# NameError: name 'T1' is not defined

# %%
# Self ia s refrance is the object

# %%
class student:
   def show(self):
    print("method called")

# %%
s1 = student()

# %%
s1.show()
# Out:
# method called

# %%
class teachers:
  def show(self):
    print("method called")

# %%
s1 = teachers()

# %%
s1.show()
# Out:
# method called

# %%
 # Magic method

# %%
# magic method are special methods with double underscore (__) that python automaticlly

# %%
# magic mehods customize object behaviour

# %%
# __init__()_ initalize object

# %%
class Students
   def __init__(self, name):
      self.name = name
# Out:
#   File "/tmp/ipykernel_7173/2961957470.py", line 1
#     class Students
#                   ^
# SyntaxError: expected ':'

# %%
s = student("Tanishka")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_7173/3982772224.py in <cell line: 0>()
# ----> 1 s = student("Tanishka")
#
# TypeError: student() takes no arguments

# %%
print(s.name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7173/2363482903.py in <cell line: 0>()
# ----> 1 print(s.name)
#
# NameError: name 's' is not defined

# %%
# Constructor called

# %%
# a constructur initializes object data when an object is created

# %%
#__init__() initalizes the object after it was been created

# %%
class studentconstructor:

    def__init__(self):
       print("constructor called")
# Out:
#   File "/tmp/ipykernel_7173/1186321164.py", line 3
#     def__init__(self):
#                      ^
# SyntaxError: invalid syntax

# %%
obj = studentconstructor:
# Out:
#   File "/tmp/ipykernel_7173/3949782156.py", line 1
#     obj = studentconstructor:
#                             ^
# SyntaxError: invalid syntax

# %%
# class  Teachersconstructor:
       def__init__self:
         print("constructor called")
# Out:
#   File "/tmp/ipykernel_7173/93244784.py", line 2
#     def__init__self:
#     ^
# IndentationError: unexpected indent

# %%
object: student constructor
# Out:
#   File "/tmp/ipykernel_7173/1091813350.py", line 1
#     object: student constructor
#                     ^
# SyntaxError: invalid syntax

# %%
# Instance variable

# %%
# Instance variable are variable that belong to an object

# %%
class student:

   def__init__(self,name):
      self.name = name  # Instance variable
# Out:
#   File "/tmp/ipykernel_7173/4039461324.py", line 3
#     def__init__(self,name):
#                           ^
# SyntaxError: invalid syntax

# %%
s1 = student("Tanishka")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_7173/3797569008.py in <cell line: 0>()
# ----> 1 s1 = student("Tanishka")
#
# TypeError: student() takes no arguments

# %%
s1.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_7173/2835019485.py in <cell line: 0>()
# ----> 1 s1.name
#
# AttributeError: 'teachers' object has no attribute 'name'

# %%
# Instance method

# %%
# Instance methods are methods that oprate on a specific object

# %%
from os import name
class student:

    def__init__(self, name):
       self.name = name

    def show(self . name):
      self
# Out:
#   File "/tmp/ipykernel_7173/369538257.py", line 4
#     def__init__(self, name):
#                            ^
# SyntaxError: invalid syntax

# %%
# Class variables

# %%
# class variable are shared by all objects

# %%
class student:
    school = "ABC school"   # class variable

    def__init__(self, name):
      self.name = name
# Out:
#   File "/tmp/ipykernel_7173/1514885217.py", line 4
#     def__init__(self, name):
#                            ^
# SyntaxError: invalid syntax

# %%
S1 = student("tanishka")
S2 = student("snehal")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_7173/2415424377.py in <cell line: 0>()
# ----> 1 S1 = student("tanishka")
#       2 S2 = student("snehal")
#
# TypeError: student() takes no arguments

# %%
s1.school
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_7173/1006816147.py in <cell line: 0>()
# ----> 1 s1.school
#
# AttributeError: 'teachers' object has no attribute 'school'

# %%
# class methods
# A class method works with the class itself, not a specific object

# %%
# classmathod tells python this is a

# %%
# Static Method

# %%
# static methods are utility methods that do not use self or

# %%
# Works with neither the object nor the class

# %%
class calculator:

  @staticmethode
  def add(a, b):
      return a + b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7173/1700223307.py in <cell line: 0>()
# ----> 1 class calculator:
#       2
#       3   @staticmethode
#       4   def add(a, b):
#       5       return a + b
#
# /tmp/ipykernel_7173/1700223307.py in calculator()
#       1 class calculator:
#       2
# ----> 3   @staticmethode
#       4   def add(a, b):
#       5       return a + b
#
# NameError: name 'staticmethode' is not defined

# %%
calculator.add
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7173/3318924196.py in <cell line: 0>()
# ----> 1 calculator.add
#
# NameError: name 'calculator' is not defined

# %%
# Encapsulation

# %%
# Encapsulation is the process of hinding

# %%
class BankAccount:

  def_init_(self, balance):
    self.__init__(self, balance):

  def get_balance(self):
      return self.__balance
# Out:
#   File "/tmp/ipykernel_7173/1276925423.py", line 3
#     def_init_(self, balance):
#                             ^
# SyntaxError: invalid syntax

# %%
BankAccount(1000).get__balance
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7173/408275618.py in <cell line: 0>()
# ----> 1 BankAccount(1000).get__balance
#
# NameError: name 'BankAccount' is not defined

# %%
# Inheritance
# single inheritance

# %%
class Animal:
  def eat(self):
    print("Eating")

class Dog(Animal):
  pass

# %%
Dog().eat()
# Out:
# Eating

# %%
#  Method overriding

# %%
# method overriding replace a parent method in the child class

# %%
class vehicle:
  def start(self):
      print("vehicle is starting...")

class car(vehicle):
  def start(self):
      print("car is starting...")
