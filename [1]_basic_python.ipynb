# %%
# variables

# %%
students_name = "Tanishka"

# %%
students_name
# Out:
# 'Tanishka'

# %%
students_age = 20

# %%
students_age
# Out:
# 20

# %%
students_marks = 80.5

# %%
students_marks
# Out:
# 80.5

# %%
# printing with labels

# %%
name = "Tanishka"

# %%
print("Name:", name)
# Out:
# Name: Tanishka

# %%
age = 20

# %%
print("Age:",age)
# Out:
# Age: 20

# %%
city = "pune"

# %%
print("city:", city)
# Out:
# city: pune

# %%
# changing variables values

# %%
course = "Python"

# %%
print("Before changing:", course)
# Out:
# Before changing: Python

# %%
course = "Data science"

# %%
print("After changing:",course)
# Out:
# After changing: Data science

# %%
# Multiple variables

# %%
a = 10
b = 20
c = 30

# %%
a
# Out:
# 10

# %%
b
# Out:
# 20

# %%
c
# Out:
# 30

# %%
x,y,z = 100,200,300

# %%
x
# Out:
# 100

# %%
y
# Out:
# 200

# %%
z
# Out:
# 300

# %%
# same value to multiple variables

# %%
math = Science = english = 90

# %%
print("Maths:", math)
# Out:
# Maths: 90

# %%
print("Science:", Science)
# Out:
# Science: 90

# %%
print("English:", english)
# Out:
# English: 90

# %%
# naming rules

# %%
student_name = "Tanishka"

# %%
_total_marks = 456

# %%
# Invalid variable names

# %%
2name = "Tanishka"
# Out:
#   File "/tmp/ipykernel_3860/1748510450.py", line 1
#     2name = "Tanishka"
#     ^
# SyntaxError: invalid decimal literal

# %%
student_name ="Tanishka"

# %%
full name ="Tanishka T"
# Out:
#   File "/tmp/ipykernel_3860/3308348846.py", line 1
#     full name ="Tanishka T"
#          ^
# SyntaxError: invalid syntax

# %%
class = "java"
# Out:
#   File "/tmp/ipykernel_3860/3441213440.py", line 1
#     class = "java"
#           ^
# SyntaxError: invalid syntax

# %%
# dynamic typing

# %%
value = 100

# %%
value
# Out:
# 100

# %%
type(value)
# Out:
# int

# %%
value = "python"

# %%
value
# Out:
# 'python'

# %%
type(value)
# Out:
# str

# %%
value = 20.5

# %%
value
# Out:
# 20.5

# %%
type(value)
# Out:
# float

# %%
# Input example

# %%
name = input("Enter your name:")

# %%
print("Name:", name)

# %%
age = input("Enter your age")

# %%
print("Age:" age)

# %%
age = int(input("Enter age"))

# %%
print(age)

# %%
type(age)

# %%
# commen escape character

# %%
print("Hello\world")

# %%
# tab space

# %%
print("Hello\tworld")

# %%
# Backlash

# %%
print("c:\\Users\\Tanishka")

# %%
# single quote

# %%
print('It\s python')

# %%
# double qoute

# %%
print("He said \"Hello\"")

# %%
# Backspace

# %%
print("Helloo\b")

# %%
# unicode character

# %%
print("\u0041")

# %%
print("\u0939")

# %%
# print function

# %%
print("Hello world")

# %%
# printing variable

# %%
name = "Tanishka"
print(name)

# %%
# printing multiple variable

# %%
name = "Tanishka"
age = 20

# %%
# printing multiple value

# %%
name = "Tanishka"
age = 20

# %%
print(name,age)

# %%
import keyword

# %%
print(keyword.kwlist)
