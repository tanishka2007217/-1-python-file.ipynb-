# %%
# 1] create a class and multiple objects

# %%
class student:
    def display(self, name, roll):
        print("Name:",name)
        print("Roll no:", roll)

s1 = student()
s2 = student()

s1.display("Tanishka", 101)
s2.display("savi", 102)
# Out:
# Name: Tanishka
# Roll no: 101
# Name: savi
# Roll no: 102

# %%
# 2] constructor Example

# %%
class student:
    def __init__(self, name, roll):
        self.name = name
        self.roll = roll

    def display(self):
        print("Name:", self.name)
        print("Roll:", self.roll)

s = student("Tanishka", 101)
s.display
# Out:
# <bound method student.display of <__main__.student object at 0x7efe40a4fd10>>

# %%
# 3] Instance variable

# %%
class student:
    def __init__(self):
        self.name = "Tanishka"

s = student()
print("Before:",s.name)

s.name = "savi"
print("After:",s.name)
# Out:
# Before: Tanishka
# After: savi

# %%
# 4] class variable

# %%
class student:
    school = "ABC College"

s1 = student()
s2 = student()

print(s1.school)
print(s2.school)

student.school = "XYZ College"

print(s1.school)
print(s2.school)
# Out:
# ABC College
# ABC College
# XYZ College
# XYZ College

# %%
# 5] Instance method

# %%
class calculator:
    def add(self, a, b):
        print("sum =", a + b)

c = calculator()
c.add(10,20)
# Out:
# sum = 30

# %%
# 6] Class Method, Static Method, Instance Method

# %%
class Demo:

    def instance_method(self):
        print("Instance Method")

    @classmethod
    def class_method(cls):
        print("Class Method")

    @staticmethod
    def static_method():
        print("Static Method")

obj = Demo()

obj.instance_method()
Demo.class_method()
Demo.static_method()
# Out:
# Instance Method
# Class Method
# Static Method

# %%
#7] Single Inheritance

# %%
class Parent:
    def show(self):
        print("Parent Class")

class Child(Parent):
    def show(self):
        print("Child Class")

c = Child()

c.show()
# Out:
# Child Class

# %%
# 8] Multilevel Inheritance

# %%
class GrandParent:
    def gp(self):
        print("GrandParent")

class Parent(GrandParent):
    def p(self):
        print("Parent")

class Child(Parent):
    def c(self):
        print("Child")

obj = Child()

obj.gp()
obj.p()
obj.c()
# Out:
# GrandParent
# Parent
# Child

# %%
# 9] Multiple Inheritance

# %%
class Father:
    def father_method(self):
        print("Father Method")

class Mother:
    def mother_method(self):
        print("Mother Method")

class Child(Father, Mother):
    pass

c = Child()

c.father_method()
c.mother_method()
# Out:
# Father Method
# Mother Method

# %%
# 10] Hierarchical Inheritance

# %%
class Parent:
    def show(self):
        print("Parent Method")

class Child1(Parent):
    pass

class Child2(Parent):
    pass

c1 = Child1()
c2 = Child2()

c1.show()
c2.show()
# Out:
# Parent Method
# Parent Method

# %%
# 11] Demonstrate Method Overriding, call overridden methods, and compare outputs.

# %%
class Animal:
    def sound(self):
        print("Animal makes a sound")

class Dog(Animal):
    def sound(self):
        print("Dog barks")

a = Animal()
d = Dog()

print("Parent Class:")
a.sound()

print("Child Class:")
d.sound()
# Out:
# Parent Class:
# Animal makes a sound
# Child Class:
# Dog barks

# %%
# 12] Demonstrate Encapsulation using private variables, getter methods, and setter methods.

# %%
class Student:
    def __init__(self):
        self.__marks = 0      # Private Variable

    # Setter Method
    def set_marks(self, marks):
        self.__marks = marks

    # Getter Method
    def get_marks(self):
        return self.__marks

s = Student()

s.set_marks(95)

print("Student Marks:", s.get_marks())
# Out:
# Student Marks: 95

# %%
# 13] Implement Polymorphism using Method Overriding.

# %%
class Bird:
    def fly(self):
        print("Bird can fly")

class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high")

class Penguin(Bird):
    def fly(self):
        print("Penguin cannot fly")

b = Bird()
s = Sparrow()
p = Penguin()

b.fly()
s.fly()
p.fly()
# Out:
# Bird can fly
# Sparrow flies high
# Penguin cannot fly

# %%
# 14] Create an Abstract Class, implement abstract methods, and instantiate child classes.

# %%
from abc import ABC, abstractmethod

class Shape(ABC):

    @abstractmethod
    def area(self):
        pass

class Square(Shape):
    def __init__(self, side):
        self.side = side

    def area(self):
        print("Area of Square =", self.side * self.side)

s = Square(4)
s.area()
# Out:
# Area of Square = 16

# %%
# 15] Demonstrate Abstraction using the abc module with multiple child classes.

# %%
from abc import ABC, abstractmethod

class Vehicle(ABC):

    @abstractmethod
    def start(self):
        pass

class Car(Vehicle):
    def start(self):
        print("Car starts with a key.")

class Bike(Vehicle):
    def start(self):
        print("Bike starts with a self-start button.")

c = Car()
b = Bike()

c.start()
b.start()
# Out:
# Car starts with a key.
# Bike starts with a self-start button.

# %%
# 16] Write a Python program to overload arithmetic operators, compare objects, and display the results.

# %%
class Number:
    def __init__(self, value):
        self.value = value

    # Overloading + operator
    def __add__(self, other):
        return self.value + other.value

    # Overloading > operator
    def __gt__(self, other):
        return self.value > other.value

n1 = Number(20)
n2 = Number(10)

print("Addition =", n1 + n2)
print("n1 > n2 =", n1 > n2)
# Out:
# Addition = 30
# n1 > n2 = True

# %%
# 17] Write a Python program to override the __str__() method, print object details, and compare with default output.

# %%
class Student:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def __str__(self):
        return f"Name: {self.name}, Age: {self.age}"

s = Student("Tanishka", 18)

print(s)
# Out:
# Name: Tanishka, Age: 18

# %%
# 18] Write a Python program to demonstrate object composition, access composed objects, and display their details.

# %%
class Engine:
    def __init__(self, engine_type):
        self.engine_type = engine_type

    def display(self):
        print("Engine Type:", self.engine_type)

class Car:
    def __init__(self, brand, engine):
        self.brand = brand
        self.engine = engine

    def display(self):
        print("Car Brand:", self.brand)
        self.engine.display()

e = Engine("Petrol")
c = Car("Toyota", e)

c.display()
# Out:
# Car Brand: Toyota
# Engine Type: Petrol

# %%
# 19] Write a Python program to create a package, import modules from the package, and call their functions.

# %%
class AddSub:
    def add(self, a, b):
        return a + b

    def sub(self, a, b):
        return a - b

obj = AddSub()

print("Addition =", obj.add(20, 10))
print("Subtraction =", obj.sub(20, 10))
# Out:
# Addition = 30
# Subtraction = 10

# %%
# 20] Write a Python program to use the collections module, create a Counter, and display frequency analysis.

# %%
from collections import Counter

text = "python programming"

count = Counter(text)

print("Character Frequency:")
print(count)
# Out:
# Character Frequency:
# Counter({'p': 2, 'o': 2, 'n': 2, 'r': 2, 'g': 2, 'm': 2, 'y': 1, 't': 1, 'h': 1, ' ': 1, 'a': 1, 'i': 1})

# %%
# 21] Write a Python program to use the datetime module to display the current date and time.

# %%
from datetime import datetime

# Get current date and time
now = datetime.now()

print("Current Date and Time:")
print(now)
# Out:
# Current Date and Time:
# 2026-07-01 17:53:06.462777

# %%
# 22] Write a Python program to create a text file, write data into it, read the data, and display the contents.

# %%
file = open("student.txt", "w")
file.write("Name: Tanishka\n")
file.write("Age: 18\n")
file.write("Course: Python")
file.close()

# Read the file
file = open("student.txt", "r")
print(file.read())
file.close()
# Out:
# Name: Tanishka
# Age: 18
# Course: Python

# %%
# 23] Write a Python program to append data to an existing file and display the updated contents.

# %%
file = open("student.txt", "a")
file.write("\nCity: Pune")
file.close()

file = open("student.txt", "r")
print(file.read())
file.close()
# Out:
# Name: Tanishka
# Age: 18
# Course: Python
# City: Pune

# %%
# 24] Write a Python program to handle exceptions using try, except, else, and finally.

# %%
try:
    a = int(input("Enter first number: "))
    b = int(input("Enter second number: "))

    result = a / b

except ZeroDivisionError:
    print("Division by zero is not allowed.")

except ValueError:
    print("Please enter valid numbers.")

else:
    print("Result =", result)

finally:
    print("Program Finished.")
# Out:
# Enter first number: 5.0
# Please enter valid numbers.
# Program Finished.

# %%
# 25] Write a Python program to create a simple Student Management System using OOP.

# %%
class Student:
    def __init__(self, roll, name, marks):
        self.roll = roll
        self.name = name
        self.marks = marks

    def display(self):
        print("Roll No :", self.roll)
        print("Name    :", self.name)
        print("Marks   :", self.marks)


students = []

while True:
    print("\n1. Add Student")
    print("2. Display Students")
    print("3. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        roll = input("Enter Roll No: ")
        name = input("Enter Name: ")
        marks = input("Enter Marks: ")

        s = Student(roll, name, marks)
        students.append(s)

        print("Student Added Successfully!")

    elif choice == "2":
        if len(students) == 0:
            print("No Student Records Found.")
        else:
            print("\nStudent Records")
            for s in students:
                s.display()
                print("--------------------")

    elif choice == "3":
        print("Thank You!")
        break

    else:
        print("Invalid Choice")
# Out:
# 1. Add Student
# 2. Display Students
# 3. Exit
# Enter your choice: Exit
# Invalid Choice
#
# 1. Add Student
# 2. Display Students
# 3. Exit
# Enter your choice: Tanishka
# Invalid Choice
#
# 1. Add Student
# 2. Display Students
# 3. Exit
# Enter your choice: 2
# No Student Records Found.
#
# 1. Add Student
# 2. Display Students
# 3. Exit
# Enter your choice: 3
# Thank You!
